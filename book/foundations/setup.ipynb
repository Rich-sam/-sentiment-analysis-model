# %% [markdown]
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/giswqs/GeoAI-Book/blob/main/book/foundations/setup.ipynb)
# [![image](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/giswqs/GeoAI-Book/main?urlpath=lab/tree/book/foundations/setup.ipynb)

# %% [markdown]
# # Setting Up Your Environment
#
# ## Introduction
#
# ## Learning Objectives
#
# ## Hardware Requirements
#
# ### Minimum Requirements
#
# ### Recommended Requirements
#
# ### Cloud Alternatives
#
# ## Installing NVIDIA Drivers
#
# ### macOS
#
# ### Windows
#
# ```bash
# nvidia-smi
# ```
#
# ### Linux
#
# ```bash
# sudo apt update
# sudo ubuntu-drivers install
# ```
#
# ```bash
# sudo apt install nvidia-driver-580
# ```
#
# ```bash
# sudo reboot
# ```
#
# ```bash
# sudo dnf install https://download1.rpmfusion.org/free/fedora/rpmfusion-free-release-$(rpm -E %fedora).noarch.rpm \
#     https://download1.rpmfusion.org/nonfree/fedora/rpmfusion-nonfree-release-$(rpm -E %fedora).noarch.rpm
# sudo dnf install akmod-nvidia
# ```
#
# ```bash
# sudo pacman -S nvidia nvidia-utils
# ```
#
# ### Verifying the Driver Installation
#
# ```bash
# nvidia-smi
# ```
#
# ## Installing Python with Miniconda
#
# ### Windows Installation
#
#    ```bash
#    curl https://repo.anaconda.com/miniconda/Miniconda3-latest-Windows-x86_64.exe -o .\miniconda.exe
#    start /wait "" .\miniconda.exe /S
#    del .\miniconda.exe
#    ```
#
#    ```bash
#    conda --version
#    python --version
#    ```
#
# ### macOS Installation
#
# ```bash
# mkdir -p ~/miniconda3
# curl https://repo.anaconda.com/miniconda/Miniconda3-latest-MacOSX-arm64.sh -o ~/miniconda3/miniconda.sh
# bash ~/miniconda3/miniconda.sh -b -u -p ~/miniconda3
# rm ~/miniconda3/miniconda.sh
# ```
#
# ```bash
# source ~/miniconda3/bin/activate
# conda init --all
# ```
#
# ```bash
# conda --version
# python --version
# ```
#
# ### Linux Installation
#
# ```bash
# mkdir -p ~/miniconda3
# wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh -O ~/miniconda3/miniconda.sh
# bash ~/miniconda3/miniconda.sh -b -u -p ~/miniconda3
# rm ~/miniconda3/miniconda.sh
# ```
#
# ```bash
# source ~/miniconda3/bin/activate
# conda init --all
# ```
#
# ```bash
# conda --version
# python --version
# ```
#
# ## Creating a Conda Environment
#
# ```bash
# conda create -n geoai python=3.13 -y
# ```
#
# ```bash
# conda activate geoai
# ```
#
# ```bash
# conda deactivate
# ```
#
# ## Installing GeoAI and PyTorch with GPU Support
#
# ```bash
# conda activate geoai
# ```
#
# ### Checking Your GPU
#
# ```bash
# nvidia-smi
# ```
#
# ### Installing GeoAI and PyTorch with CUDA
#
# ```bash
# conda install -c conda-forge geoai segment-geospatial "pytorch=*=cuda*"
# ```
#
# ```bash
# conda install -c conda-forge geoai segment-geospatial "pytorch=2.7.0=cuda128"
# ```
#
# ### Installing GeoAI and PyTorch for CPU Only
#
# ```bash
# conda install -c conda-forge geoai segment-geospatial
# ```
#
# ### Verifying GPU Access
#
# ```bash
# python -c "import torch; print(f'PyTorch {torch.__version__}'); print(f'CUDA available: {torch.cuda.is_available()}'); print(f'GPU: {torch.cuda.get_device_name(0)}' if torch.cuda.is_available() else 'CPU only')"
# ```
#
# ## Installing uv as an Alternative Package Manager
#
# ```bash
# curl -LsSf https://astral.sh/uv/install.sh | sh
# ```
#
# ```bash
# pip install uv
# ```
#
# ```bash
# uv venv --python 3.13
# ```
#
# ```bash
# source .venv/bin/activate
# ```
#
# ```bash
# uv pip install geoai-py segment-geospatial jupyterlab
# ```
#
# ## Setting Up Jupyter
#
# ```bash
# jupyter lab
# ```

# %%
pip install geoai-py segment-geospatial jupyterlab
# Out:
# Collecting geoai-py
#   Downloading geoai_py-0.40.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting segment-geospatial
#   Downloading segment_geospatial-1.4.0-py2.py3-none-any.whl.metadata (16 kB)
# Collecting jupyterlab
#   Downloading jupyterlab-4.6.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.12/dist-packages (from geoai-py) (2.0.8)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from geoai-py) (8.4.2)
# Collecting contextily (from geoai-py)
#   Downloading contextily-1.7.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting datasets>=4.8.4 (from geoai-py)
#   Downloading datasets-5.0.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.12/dist-packages (from geoai-py) (1.1.3)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from geoai-py) (1.20.1)
# Collecting jupyter-server-proxy (from geoai-py)
#   Downloading jupyter_server_proxy-4.5.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting leafmap>=0.61.1 (from geoai-py)
#   Downloading leafmap-0.62.0-py2.py3-none-any.whl.metadata (17 kB)
# Collecting localtileserver (from geoai-py)
#   Downloading localtileserver-1.0.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: mapclassify in /usr/local/lib/python3.12/dist-packages (from geoai-py) (2.10.0)
# Collecting maplibre (from geoai-py)
#   Downloading maplibre-0.3.6-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from geoai-py) (4.13.0.92)
# Collecting overturemaps (from geoai-py)
#   Downloading overturemaps-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting planetary-computer (from geoai-py)
#   Downloading planetary_computer-1.0.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (from geoai-py) (18.1.0)
# Collecting pystac-client (from geoai-py)
#   Downloading pystac_client-0.9.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (from geoai-py) (1.5.0)
# Collecting rioxarray (from geoai-py)
#   Downloading rioxarray-0.22.0-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from geoai-py) (0.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from geoai-py) (1.6.1)
# Collecting smoothify (from geoai-py)
#   Downloading smoothify-0.3.2-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (from geoai-py) (1.0.27)
# Requirement already satisfied: tokenizers>=0.22.2 in /usr/local/lib/python3.12/dist-packages (from geoai-py) (0.22.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from geoai-py) (2.11.0+cpu)
# Collecting torchgeo (from geoai-py)
#   Downloading torchgeo-0.9.0-py3-none-any.whl.metadata (19 kB)
# Collecting torchinfo (from geoai-py)
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from geoai-py) (4.67.3)
# Requirement already satisfied: transformers>=4.56.2 in /usr/local/lib/python3.12/dist-packages (from geoai-py) (5.12.1)
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (from segment-geospatial) (5.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from segment-geospatial) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from segment-geospatial) (2.0.2)
# Collecting patool (from segment-geospatial)
#   Downloading patool-4.0.5-py2.py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from segment-geospatial) (11.3.0)
# Requirement already satisfied: pyproj in /usr/local/lib/python3.12/dist-packages (from segment-geospatial) (3.7.2)
# Collecting segment_anything (from segment-geospatial)
#   Downloading segment_anything-1.0-py3-none-any.whl.metadata (487 bytes)
# Requirement already satisfied: shapely in /usr/local/lib/python3.12/dist-packages (from segment-geospatial) (2.1.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from segment-geospatial) (0.26.0+cpu)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.12/dist-packages (from segment-geospatial) (2026.3.0)
# Collecting async-lru>=1.0.0 (from jupyterlab)
#   Downloading async_lru-2.3.0-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab) (0.28.1)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab) (6.17.1)
# Requirement already satisfied: jinja2>=3.0.3 in /usr/local/lib/python3.12/dist-packages (from jupyterlab) (3.1.6)
# Collecting jupyter-builder>=1.0.2 (from jupyterlab)
#   Downloading jupyter_builder-1.0.2-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.12/dist-packages (from jupyterlab) (5.9.1)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab)
#   Downloading jupyter_lsp-2.3.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting jupyter-server<3,>=2.19.0 (from jupyterlab)
#   Downloading jupyter_server-2.20.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting jupyterlab-server<3,>=2.28.0 (from jupyterlab)
#   Downloading jupyterlab_server-2.28.0-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: notebook-shim>=0.2 in /usr/local/lib/python3.12/dist-packages (from jupyterlab) (0.2.4)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.12/dist-packages (from jupyterlab) (26.2)
# Requirement already satisfied: tornado>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab) (6.5.7)
# Requirement already satisfied: traitlets in /usr/local/lib/python3.12/dist-packages (from jupyterlab) (5.7.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=4.8.4->geoai-py) (3.29.4)
# Collecting pyarrow (from geoai-py)
#   Downloading pyarrow-24.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=4.8.4->geoai-py) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets>=4.8.4->geoai-py) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets>=4.8.4->geoai-py) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=4.8.4->geoai-py) (3.7.1)
# Requirement already satisfied: multiprocess<0.70.20 in /usr/local/lib/python3.12/dist-packages (from datasets>=4.8.4->geoai-py) (0.70.16)
# Requirement already satisfied: fsspec<=2026.4.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2026.4.0,>=2023.1.0->datasets>=4.8.4->geoai-py) (2025.3.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets>=4.8.4->geoai-py) (6.0.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab) (4.14.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->geoai-py) (1.5.1)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->geoai-py) (0.25.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->geoai-py) (4.15.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (1.8.15)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (7.34.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.2.2)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab) (26.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=3.0.3->jupyterlab) (3.0.3)
# Requirement already satisfied: argon2-cffi>=21.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.19.0->jupyterlab) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.19.0->jupyterlab) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.19.0->jupyterlab) (0.5.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.19.0->jupyterlab) (7.17.1)
# Requirement already satisfied: nbformat>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.19.0->jupyterlab) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.19.0->jupyterlab) (0.25.0)
# Requirement already satisfied: send2trash>=1.8.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.19.0->jupyterlab) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.19.0->jupyterlab) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.19.0->jupyterlab) (1.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core->jupyterlab) (4.10.0)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab) (2.18.0)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.28.0->jupyterlab)
#   Downloading json5-0.15.0-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab) (4.26.0)
# Requirement already satisfied: anywidget in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.61.1->geoai-py) (0.9.21)
# Requirement already satisfied: bqplot in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.61.1->geoai-py) (0.12.47)
# Collecting duckdb>=1.4.1 (from leafmap>=0.61.1->geoai-py)
#   Downloading duckdb-1.5.4-cp312-cp312-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: folium in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.61.1->geoai-py) (0.20.0)
# Collecting geojson (from leafmap>=0.61.1->geoai-py)
#   Downloading geojson-3.3.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: ipyevents in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.61.1->geoai-py) (2.0.4)
# Requirement already satisfied: ipyfilechooser in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.61.1->geoai-py) (0.6.0)
# Requirement already satisfied: ipyleaflet in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.61.1->geoai-py) (0.20.0)
# Collecting ipyvue>=1.12.0 (from leafmap>=0.61.1->geoai-py)
#   Downloading ipyvue-1.12.0-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting ipyvuetify (from leafmap>=0.61.1->geoai-py)
#   Downloading ipyvuetify-1.11.3-py2.py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.61.1->geoai-py) (7.7.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.61.1->geoai-py) (5.24.1)
# Requirement already satisfied: python-box in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.61.1->geoai-py) (7.4.1)
# Requirement already satisfied: scooby in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.61.1->geoai-py) (0.11.2)
# Collecting whiteboxgui (from leafmap>=0.61.1->geoai-py)
#   Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.56.2->geoai-py) (2025.11.3)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.56.2->geoai-py) (0.8.0)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from albumentations->geoai-py) (1.16.3)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.12/dist-packages (from albumentations->geoai-py) (2.13.4)
# Requirement already satisfied: albucore==0.0.24 in /usr/local/lib/python3.12/dist-packages (from albumentations->geoai-py) (0.0.24)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations->geoai-py) (4.6.2)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations->geoai-py) (6.5.16)
# Requirement already satisfied: geopy in /usr/local/lib/python3.12/dist-packages (from contextily->geoai-py) (2.4.1)
# Collecting mercantile (from contextily->geoai-py)
#   Downloading mercantile-1.2.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from contextily->geoai-py) (1.5.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown->segment-geospatial) (4.13.5)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas->geoai-py) (0.12.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from jupyter-server-proxy->geoai-py) (3.14.1)
# Collecting simpervisor>=1.0.0 (from jupyter-server-proxy->geoai-py)
#   Downloading simpervisor-1.0.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: fastapi>=0.100.0 in /usr/local/lib/python3.12/dist-packages (from localtileserver->geoai-py) (0.138.0)
# Requirement already satisfied: uvicorn[standard] in /usr/local/lib/python3.12/dist-packages (from localtileserver->geoai-py) (0.49.0)
# Collecting jupyter-loopback>=0.3.3 (from jupyter-loopback[comm]>=0.3.3->localtileserver->geoai-py)
#   Downloading jupyter_loopback-0.3.3-py3-none-any.whl.metadata (7.6 kB)
# Collecting rio-tiler (from localtileserver->geoai-py)
#   Downloading rio_tiler-9.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting rio-cogeo (from localtileserver->geoai-py)
#   Downloading rio_cogeo-7.0.2-py3-none-any.whl.metadata (6.1 kB)
# Collecting server-thread (from localtileserver->geoai-py)
#   Downloading server_thread-0.3.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: networkx>=3.2 in /usr/local/lib/python3.12/dist-packages (from mapclassify->geoai-py) (3.6.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->geoai-py) (3.6.0)
# Requirement already satisfied: branca in /usr/local/lib/python3.12/dist-packages (from maplibre->geoai-py) (0.8.2)
# Collecting eval-type-backport (from maplibre->geoai-py)
#   Downloading eval_type_backport-0.4.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->segment-geospatial) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->segment-geospatial) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->segment-geospatial) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->segment-geospatial) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->segment-geospatial) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->segment-geospatial) (2.9.0.post0)
# Collecting colorama>=0.4.6 (from overturemaps->geoai-py)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: orjson>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from overturemaps->geoai-py) (3.11.9)
# Collecting pyfiglet>=1.0.2 (from overturemaps->geoai-py)
#   Downloading pyfiglet-1.0.4-py3-none-any.whl.metadata (7.4 kB)
# Collecting pystac>=1.0.0 (from planetary-computer->geoai-py)
#   Downloading pystac-1.15.1-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: pytz>=2020.5 in /usr/local/lib/python3.12/dist-packages (from planetary-computer->geoai-py) (2025.2)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from planetary-computer->geoai-py) (1.2.2)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio->geoai-py) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio->geoai-py) (26.1.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio->geoai-py) (0.7.2)
# Collecting xarray>=2026.2 (from rioxarray->geoai-py)
#   Downloading xarray-2026.4.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->geoai-py) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->geoai-py) (2026.4.11)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->geoai-py) (0.5)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch->geoai-py) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->geoai-py) (1.14.0)
# Requirement already satisfied: einops>=0.3 in /usr/local/lib/python3.12/dist-packages (from torchgeo->geoai-py) (0.8.2)
# Collecting jsonargparse>=4.35 (from jsonargparse[signatures]>=4.35->torchgeo->geoai-py)
#   Downloading jsonargparse-4.49.0-py3-none-any.whl.metadata (12 kB)
# Collecting kornia>=0.8.2 (from torchgeo->geoai-py)
#   Downloading kornia-0.8.3-py3-none-any.whl.metadata (22 kB)
# Collecting lightly!=1.4.26,>=1.4.5 (from torchgeo->geoai-py)
#   Downloading lightly-1.5.25-py3-none-any.whl.metadata (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 kB 2.8 MB/s eta 0:00:00
# Collecting lightning!=2.3.*,!=2.5.0,!=2.5.5,!=2.5.6,>=2 (from torchgeo->geoai-py)
#   Downloading lightning-2.6.5-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.8 MB/s eta 0:00:00
# Collecting segmentation-models-pytorch>=0.5 (from torchgeo->geoai-py)
#   Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl.metadata (17 kB)
# Collecting torchmetrics>=1.2 (from torchgeo->geoai-py)
#   Downloading torchmetrics-1.9.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.19.0->jupyterlab) (25.1.0)
# Requirement already satisfied: starlette>=0.46.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.100.0->localtileserver->geoai-py) (1.3.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.100.0->localtileserver->geoai-py) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.100.0->localtileserver->geoai-py) (0.0.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->geoai-py) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->geoai-py) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->geoai-py) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->geoai-py) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->geoai-py) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->geoai-py) (1.24.2)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab)
#   Downloading jedi-0.20.0-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (2.20.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (4.9.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap>=0.61.1->geoai-py) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap>=0.61.1->geoai-py) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap>=0.61.1->geoai-py) (3.0.16)
# Requirement already satisfied: docstring-parser>=0.17 in /usr/local/lib/python3.12/dist-packages (from jsonargparse[signatures]>=4.35->torchgeo->geoai-py) (0.18.0)
# Collecting typeshed-client>=2.8.2 (from jsonargparse[signatures]>=4.35->torchgeo->geoai-py)
#   Downloading typeshed_client-2.12.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab) (2026.5.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab) (4.1.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab) (0.1.1)
# Requirement already satisfied: psygnal>=0.8.1 in /usr/local/lib/python3.12/dist-packages (from anywidget->leafmap>=0.61.1->geoai-py) (0.15.1)
# Collecting kornia-rs>=0.1.9 (from kornia>=0.8.2->torchgeo->geoai-py)
#   Downloading kornia_rs-0.1.14-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Collecting hydra-core>=1.0.0 (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py)
#   Downloading hydra_core-1.3.3-py3-none-any.whl.metadata (5.7 kB)
# Collecting lightly_utils~=0.0.0 (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py)
#   Downloading lightly_utils-0.0.2-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.12/dist-packages (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py) (1.17.0)
# Collecting pytorch_lightning>=1.0.4 (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py)
#   Downloading pytorch_lightning-2.6.5-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: urllib3>=1.25.3 in /usr/local/lib/python3.12/dist-packages (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py) (2.5.0)
# Collecting aenum>=3.1.11 (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py)
#   Downloading aenum-3.1.17-py3-none-any.whl.metadata (3.8 kB)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning!=2.3.*,!=2.5.0,!=2.5.5,!=2.5.6,>=2->torchgeo->geoai-py)
#   Downloading lightning_utilities-0.15.3-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.19.0->jupyterlab) (6.4.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.19.0->jupyterlab) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.19.0->jupyterlab) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.19.0->jupyterlab) (3.3.2)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.19.0->jupyterlab) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.19.0->jupyterlab) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.19.0->jupyterlab) (2.21.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=4.8.4->geoai-py) (2026.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations->geoai-py) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations->geoai-py) (2.46.4)
# Collecting pystac-core<2,>=1.15.0 (from pystac>=1.0.0->planetary-computer->geoai-py)
#   Downloading pystac_core-1.15.1-py3-none-any.whl.metadata (1.3 kB)
# Collecting pystac-ext-classification (from pystac>=1.0.0->planetary-computer->geoai-py)
#   Downloading pystac_ext_classification-2.0.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting pystac-ext-datacube (from pystac>=1.0.0->planetary-computer->geoai-py)
#   Downloading pystac_ext_datacube-2.2.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-eo (from pystac>=1.0.0->planetary-computer->geoai-py)
#   Downloading pystac_ext_eo-1.1.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting pystac-ext-file (from pystac>=1.0.0->planetary-computer->geoai-py)
#   Downloading pystac_ext_file-2.1.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-grid (from pystac>=1.0.0->planetary-computer->geoai-py)
#   Downloading pystac_ext_grid-1.1.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting pystac-ext-item-assets (from pystac>=1.0.0->planetary-computer->geoai-py)
#   Downloading pystac_ext_item_assets-1.0.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting pystac-ext-label (from pystac>=1.0.0->planetary-computer->geoai-py)
#   Downloading pystac_ext_label-1.0.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting pystac-ext-mgrs (from pystac>=1.0.0->planetary-computer->geoai-py)
#   Downloading pystac_ext_mgrs-1.0.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-mlm (from pystac>=1.0.0->planetary-computer->geoai-py)
#   Downloading pystac_ext_mlm-1.4.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting pystac-ext-pointcloud (from pystac>=1.0.0->planetary-computer->geoai-py)
#   Downloading pystac_ext_pointcloud-1.0.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-projection (from pystac>=1.0.0->planetary-computer->geoai-py)
#   Downloading pystac_ext_projection-2.0.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting pystac-ext-raster (from pystac>=1.0.0->planetary-computer->geoai-py)
#   Downloading pystac_ext_raster-1.1.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting pystac-ext-render (from pystac>=1.0.0->planetary-computer->geoai-py)
#   Downloading pystac_ext_render-2.0.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-sar (from pystac>=1.0.0->planetary-computer->geoai-py)
#   Downloading pystac_ext_sar-1.0.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-sat (from pystac>=1.0.0->planetary-computer->geoai-py)
#   Downloading pystac_ext_sat-1.0.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-scientific (from pystac>=1.0.0->planetary-computer->geoai-py)
#   Downloading pystac_ext_scientific-1.0.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-storage (from pystac>=1.0.0->planetary-computer->geoai-py)
#   Downloading pystac_ext_storage-2.0.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting pystac-ext-table (from pystac>=1.0.0->planetary-computer->geoai-py)
#   Downloading pystac_ext_table-1.2.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-timestamps (from pystac>=1.0.0->planetary-computer->geoai-py)
#   Downloading pystac_ext_timestamps-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-version (from pystac>=1.0.0->planetary-computer->geoai-py)
#   Downloading pystac_ext_version-1.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting pystac-ext-view (from pystac>=1.0.0->planetary-computer->geoai-py)
#   Downloading pystac_ext_view-1.0.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting pystac-ext-xarray-assets (from pystac>=1.0.0->planetary-computer->geoai-py)
#   Downloading pystac_ext_xarray_assets-1.0.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=4.8.4->geoai-py) (3.4.7)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->geoai-py) (1.3.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.12/dist-packages (from terminado>=0.8.3->jupyter-server<3,>=2.19.0->jupyterlab) (0.7.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface_hub->geoai-py) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.26.0,>=0.20.0->huggingface_hub->geoai-py) (13.9.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown->segment-geospatial) (2.8.4)
# Requirement already satisfied: traittypes>=0.0.6 in /usr/local/lib/python3.12/dist-packages (from bqplot->leafmap>=0.61.1->geoai-py) (0.2.3)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.12/dist-packages (from geopy->contextily->geoai-py) (2.1)
# Requirement already satisfied: jupyter-leaflet<0.21,>=0.20 in /usr/local/lib/python3.12/dist-packages (from ipyleaflet->leafmap>=0.61.1->geoai-py) (0.20.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->leafmap>=0.61.1->geoai-py) (9.1.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->segment-geospatial) (1.7.1)
# Collecting morecantile<8.0,>=5.0 (from rio-cogeo->localtileserver->geoai-py)
#   Downloading morecantile-7.0.3-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from rio-tiler->localtileserver->geoai-py) (6.2.6)
# Collecting color-operations (from rio-tiler->localtileserver->geoai-py)
#   Downloading color_operations-0.2.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: httpx2 in /usr/local/lib/python3.12/dist-packages (from rio-tiler->localtileserver->geoai-py) (2.4.0)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.12/dist-packages (from rio-tiler->localtileserver->geoai-py) (2.14.1)
# Requirement already satisfied: werkzeug in /usr/local/lib/python3.12/dist-packages (from server-thread->localtileserver->geoai-py) (3.1.8)
# Requirement already satisfied: httptools>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]->localtileserver->geoai-py) (0.8.0)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]->localtileserver->geoai-py) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]->localtileserver->geoai-py) (1.2.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]->localtileserver->geoai-py) (15.0.1)
# Collecting ipytree (from whiteboxgui->leafmap>=0.61.1->geoai-py)
#   Downloading ipytree-0.2.2-py2.py3-none-any.whl.metadata (849 bytes)
# Collecting whitebox (from whiteboxgui->leafmap>=0.61.1->geoai-py)
#   Downloading whitebox-2.3.6-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.19.0->jupyterlab) (0.5.1)
# Requirement already satisfied: tinycss2>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.19.0->jupyterlab) (1.5.1)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /usr/local/lib/python3.12/dist-packages (from hydra-core>=1.0.0->lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py) (2.3.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from hydra-core>=1.0.0->lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py) (4.9.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.8.7)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab) (25.10.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab) (0.8.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub->geoai-py) (4.2.0)
# Requirement already satisfied: importlib_resources>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from typeshed-client>=2.8.2->jsonargparse[signatures]>=4.35->torchgeo->geoai-py) (7.1.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.12/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->leafmap>=0.61.1->geoai-py) (6.5.7)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.19.0->jupyterlab) (2.0.0)
# Requirement already satisfied: httpcore2==2.4.0 in /usr/local/lib/python3.12/dist-packages (from httpx2->rio-tiler->localtileserver->geoai-py) (2.4.0)
# Requirement already satisfied: truststore>=0.10 in /usr/local/lib/python3.12/dist-packages (from httpx2->rio-tiler->localtileserver->geoai-py) (0.10.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.19.0->jupyterlab) (3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface_hub->geoai-py) (0.1.2)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap>=0.61.1->geoai-py) (1.3.3)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab) (1.4.0)
# Downloading geoai_py-0.40.1-py2.py3-none-any.whl (624 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 624.5/624.5 kB 15.4 MB/s eta 0:00:00
# Downloading segment_geospatial-1.4.0-py2.py3-none-any.whl (153 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.6/153.6 kB 10.7 MB/s eta 0:00:00
# Downloading jupyterlab-4.6.1-py3-none-any.whl (17.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.2/17.2 MB 50.7 MB/s eta 0:00:00
# Downloading async_lru-2.3.0-py3-none-any.whl (8.4 kB)
# Downloading datasets-5.0.0-py3-none-any.whl (555 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 555.1/555.1 kB 31.0 MB/s eta 0:00:00
# Downloading jupyter_builder-1.0.2-py3-none-any.whl (910 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 910.8/910.8 kB 42.7 MB/s eta 0:00:00
# Downloading jupyter_lsp-2.3.1-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 3.4 MB/s eta 0:00:00
# Downloading jupyter_server-2.20.0-py3-none-any.whl (393 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 kB 22.9 MB/s eta 0:00:00
# Downloading jupyterlab_server-2.28.0-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 3.4 MB/s eta 0:00:00
# Downloading leafmap-0.62.0-py2.py3-none-any.whl (667 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 667.5/667.5 kB 34.6 MB/s eta 0:00:00
# Downloading pyarrow-24.0.0-cp312-cp312-manylinux_2_28_x86_64.whl (48.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 MB 21.6 MB/s eta 0:00:00
# Downloading contextily-1.7.0-py3-none-any.whl (16 kB)
# Downloading jupyter_server_proxy-4.5.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 2.2 MB/s eta 0:00:00
# Downloading localtileserver-1.0.0-py3-none-any.whl (33.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.7/33.7 MB 23.9 MB/s eta 0:00:00
# Downloading maplibre-0.3.6-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 52.5 MB/s eta 0:00:00
# Downloading overturemaps-1.0.1-py3-none-any.whl (25 kB)
# Downloading patool-4.0.5-py2.py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.4/101.4 kB 6.4 MB/s eta 0:00:00
# Downloading planetary_computer-1.0.0-py3-none-any.whl (14 kB)
# Downloading pystac_client-0.9.0-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 2.6 MB/s eta 0:00:00
# Downloading rioxarray-0.22.0-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 5.1 MB/s eta 0:00:00
# Downloading segment_anything-1.0-py3-none-any.whl (36 kB)
# Downloading smoothify-0.3.2-py3-none-any.whl (26 kB)
# Downloading torchgeo-0.9.0-py3-none-any.whl (688 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 688.1/688.1 kB 35.0 MB/s eta 0:00:00
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading duckdb-1.5.4-cp312-cp312-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (21.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 65.5 MB/s eta 0:00:00
# Downloading ipyvue-1.12.0-py2.py3-none-any.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 81.5 MB/s eta 0:00:00
# Downloading json5-0.15.0-py3-none-any.whl (36 kB)
# Downloading jsonargparse-4.49.0-py3-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.7 MB/s eta 0:00:00
# Downloading jupyter_loopback-0.3.3-py3-none-any.whl (37 kB)
# Downloading kornia-0.8.3-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 51.0 MB/s eta 0:00:00
# Downloading lightly-1.5.25-py3-none-any.whl (871 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.8/871.8 kB 43.3 MB/s eta 0:00:00
# Downloading lightning-2.6.5-py3-none-any.whl (848 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 848.6/848.6 kB 40.5 MB/s eta 0:00:00
# Downloading pyfiglet-1.0.4-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 64.1 MB/s eta 0:00:00
# Downloading pystac-1.15.1-py3-none-any.whl (5.1 kB)
# Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 10.2 MB/s eta 0:00:00
# Downloading simpervisor-1.0.0-py3-none-any.whl (8.3 kB)
# Downloading torchmetrics-1.9.0-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 45.8 MB/s eta 0:00:00
# Downloading xarray-2026.4.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 57.8 MB/s eta 0:00:00
# Downloading eval_type_backport-0.4.0-py3-none-any.whl (6.4 kB)
# Downloading geojson-3.3.0-py3-none-any.whl (15 kB)
# Downloading ipyvuetify-1.11.3-py2.py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 88.2 MB/s eta 0:00:00
# Downloading mercantile-1.2.1-py3-none-any.whl (14 kB)
# Downloading rio_cogeo-7.0.2-py3-none-any.whl (21 kB)
# Downloading rio_tiler-9.3.0-py3-none-any.whl (315 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.6/315.6 kB 19.3 MB/s eta 0:00:00
# Downloading server_thread-0.3.0-py3-none-any.whl (6.6 kB)
# Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 8.1 MB/s eta 0:00:00
# Downloading aenum-3.1.17-py3-none-any.whl (165 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.6/165.6 kB 11.9 MB/s eta 0:00:00
# Downloading hydra_core-1.3.3-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 kB 11.2 MB/s eta 0:00:00
# Downloading jedi-0.20.0-py2.py3-none-any.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 84.7 MB/s eta 0:00:00
# Downloading kornia_rs-0.1.14-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 93.1 MB/s eta 0:00:00
# Downloading lightly_utils-0.0.2-py3-none-any.whl (6.4 kB)
# Downloading lightning_utilities-0.15.3-py3-none-any.whl (31 kB)
# Downloading morecantile-7.0.3-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.7 MB/s eta 0:00:00
# Downloading pystac_core-1.15.1-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.0/119.0 kB 9.8 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.6.5-py3-none-any.whl (852 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 852.4/852.4 kB 43.6 MB/s eta 0:00:00
# Downloading typeshed_client-2.12.0-py3-none-any.whl (796 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 796.9/796.9 kB 39.0 MB/s eta 0:00:00
# Downloading color_operations-0.2.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (204 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.3/204.3 kB 14.4 MB/s eta 0:00:00
# Downloading ipytree-0.2.2-py2.py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 57.4 MB/s eta 0:00:00
# Downloading pystac_ext_classification-2.0.0-py3-none-any.whl (7.0 kB)
# Downloading pystac_ext_datacube-2.2.0-py3-none-any.whl (6.8 kB)
# Downloading pystac_ext_eo-1.1.0-py3-none-any.whl (7.4 kB)
# Downloading pystac_ext_file-2.1.0-py3-none-any.whl (5.5 kB)
# Downloading pystac_ext_grid-1.1.0-py3-none-any.whl (3.3 kB)
# Downloading pystac_ext_item_assets-1.0.0-py3-none-any.whl (3.4 kB)
# Downloading pystac_ext_label-1.0.1-py3-none-any.whl (7.9 kB)
# Downloading pystac_ext_mgrs-1.0.0-py3-none-any.whl (3.8 kB)
# Downloading pystac_ext_mlm-1.4.0-py3-none-any.whl (13 kB)
# Downloading pystac_ext_pointcloud-1.0.0-py3-none-any.whl (6.2 kB)
# Downloading pystac_ext_projection-2.0.0-py3-none-any.whl (7.1 kB)
# Downloading pystac_ext_raster-1.1.0-py3-none-any.whl (6.6 kB)
# Downloading pystac_ext_render-2.0.0-py3-none-any.whl (5.0 kB)
# Downloading pystac_ext_sar-1.0.0-py3-none-any.whl (6.3 kB)
# Downloading pystac_ext_sat-1.0.0-py3-none-any.whl (4.6 kB)
# Downloading pystac_ext_scientific-1.0.0-py3-none-any.whl (5.2 kB)
# Downloading pystac_ext_storage-2.0.0-py3-none-any.whl (7.4 kB)
# Downloading pystac_ext_table-1.2.0-py3-none-any.whl (4.4 kB)
# Downloading pystac_ext_timestamps-1.1.0-py3-none-any.whl (4.3 kB)
# Downloading pystac_ext_version-1.2.0-py3-none-any.whl (5.4 kB)
# Downloading pystac_ext_view-1.0.0-py3-none-any.whl (4.5 kB)
# Downloading pystac_ext_xarray_assets-1.0.0-py3-none-any.whl (3.6 kB)
# Downloading whitebox-2.3.6-py2.py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 kB 5.3 MB/s eta 0:00:00
# Installing collected packages: segment_anything, aenum, whitebox, typeshed-client, torchinfo, simpervisor, pyfiglet, pyarrow, patool, mercantile, lightning-utilities, lightly_utils, kornia-rs, jsonargparse, json5, jedi, geojson, eval-type-backport, duckdb, colorama, color-operations, async-lru, server-thread, pystac-core, overturemaps, jupyter-builder, hydra-core, xarray, torchmetrics, pystac-ext-xarray-assets, pystac-ext-view, pystac-ext-version, pystac-ext-timestamps, pystac-ext-table, pystac-ext-storage, pystac-ext-scientific, pystac-ext-sat, pystac-ext-sar, pystac-ext-render, pystac-ext-raster, pystac-ext-projection, pystac-ext-pointcloud, pystac-ext-mlm, pystac-ext-mgrs, pystac-ext-label, pystac-ext-item-assets, pystac-ext-grid, pystac-ext-file, pystac-ext-eo, pystac-ext-datacube, pystac-ext-classification, morecantile, maplibre, kornia, contextily, smoothify, rioxarray, rio-cogeo, pytorch_lightning, pystac, segment-geospatial, rio-tiler, lightning, lightly, datasets, segmentation-models-pytorch, pystac-client, torchgeo, planetary-computer, jupyter-server, jupyterlab-server, jupyter-server-proxy, jupyter-lsp, jupyter-loopback, jupyterlab, ipyvue, ipytree, whiteboxgui, ipyvuetify, localtileserver, leafmap, geoai-py
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
#   Attempting uninstall: duckdb
#     Found existing installation: duckdb 1.3.2
#     Uninstalling duckdb-1.3.2:
#       Successfully uninstalled duckdb-1.3.2
#   Attempting uninstall: xarray
#     Found existing installation: xarray 2025.12.0
#     Uninstalling xarray-2025.12.0:
#       Successfully uninstalled xarray-2025.12.0
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
#   Attempting uninstall: jupyter-server
#     Found existing installation: jupyter_server 2.18.2
#     Uninstalling jupyter_server-2.18.2:
#       Successfully uninstalled jupyter_server-2.18.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires jupyter-server==2.18.2, but you have jupyter-server 2.20.0 which is incompatible.
# Successfully installed aenum-3.1.17 async-lru-2.3.0 color-operations-0.2.0 colorama-0.4.6 contextily-1.7.0 datasets-5.0.0 duckdb-1.5.4 eval-type-backport-0.4.0 geoai-py-0.40.1 geojson-3.3.0 hydra-core-1.3.3 ipytree-0.2.2 ipyvue-1.12.0 ipyvuetify-1.11.3 jedi-0.20.0 json5-0.15.0 jsonargparse-4.49.0 jupyter-builder-1.0.2 jupyter-loopback-0.3.3 jupyter-lsp-2.3.1 jupyter-server-2.20.0 jupyter-server-proxy-4.5.0 jupyterlab-4.6.1 jupyterlab-server-2.28.0 kornia-0.8.3 kornia-rs-0.1.14 leafmap-0.62.0 lightly-1.5.25 lightly_utils-0.0.2 lightning-2.6.5 lightning-utilities-0.15.3 localtileserver-1.0.0 maplibre-0.3.6 mercantile-1.2.1 morecantile-7.0.3 overturemaps-1.0.1 patool-4.0.5 planetary-computer-1.0.0 pyarrow-24.0.0 pyfiglet-1.0.4 pystac-1.15.1 pystac-client-0.9.0 pystac-core-1.15.1 pystac-ext-classification-2.0.0 pystac-ext-datacube-2.2.0 pystac-ext-eo-1.1.0 pystac-ext-file-2.1.0 pystac-ext-grid-1.1.0 pystac-ext-item-assets-1.0.0 pystac-ext-label-1.0.1 pystac-ext-mgrs-1.0.0 pystac-ext-mlm-1.4.0 pystac-ext-pointcloud-1.0.0 pystac-ext-projection-2.0.0 pystac-ext-raster-1.1.0 pystac-ext-render-2.0.0 pystac-ext-sar-1.0.0 pystac-ext-sat-1.0.0 pystac-ext-scientific-1.0.0 pystac-ext-storage-2.0.0 pystac-ext-table-1.2.0 pystac-ext-timestamps-1.1.0 pystac-ext-version-1.2.0 pystac-ext-view-1.0.0 pystac-ext-xarray-assets-1.0.0 pytorch_lightning-2.6.5 rio-cogeo-7.0.2 rio-tiler-9.3.0 rioxarray-0.22.0 segment-geospatial-1.4.0 segment_anything-1.0 segmentation-models-pytorch-0.5.0 server-thread-0.3.0 simpervisor-1.0.0 smoothify-0.3.2 torchgeo-0.9.0 torchinfo-1.8.0 torchmetrics-1.9.0 typeshed-client-2.12.0 whitebox-2.3.6 whiteboxgui-2.3.0 xarray-2026.4.0

# %%
import torch
import geoai

print(torch.cuda.is_available())
print(geoai.__version__)
# Out:
# False
# 0.40.1

# %% [markdown]
# ## Installing Visual Studio Code
#
# ### Download and Installation
#
# ### Recommended Extensions
#
# ```bash
# code --install-extension ms-python.python
# code --install-extension ms-toolsai.jupyter
# code --install-extension charliermarsh.ruff
# ```
#
# ## Verifying Your Setup

# %%
import sys
import importlib

print(f"Python version: {sys.version}\n")

# Check core packages
packages = {
    "torch": "PyTorch",
    "torchvision": "TorchVision",
    "geoai": "GeoAI",
    "leafmap": "Leafmap",
    "geopandas": "GeoPandas",
    "rasterio": "Rasterio",
    "samgeo": "Segment-Geospatial",
    "torchgeo": "TorchGeo",
}

for module_name, display_name in packages.items():
    try:
        mod = importlib.import_module(module_name)
        version = getattr(mod, "__version__", "installed")
        print(f"  {display_name}: {version}")
    except ImportError:
        print(f"  {display_name}: NOT FOUND")

# Check GPU availability
import torch

print(f"\nCUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU device: {torch.cuda.get_device_name(0)}")
    print(f"CUDA version: {torch.version.cuda}")
else:
    print("Running in CPU-only mode.")
# Out:
# Python version: 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
#
#   PyTorch: 2.11.0+cpu
#   TorchVision: 0.26.0+cpu
#   GeoAI: 0.40.1
#   Leafmap: 0.62.0
#   GeoPandas: 1.1.3
#   Rasterio: 1.5.0
#   Segment-Geospatial: 1.4.0
#   TorchGeo: 0.9.0
#
# CUDA available: False
# Running in CPU-only mode.

# %%
import leafmap

m = leafmap.Map(center=[40, -100], zoom=4)
m
# Out:
# Map(center=[40, -100], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_t…

# %%
import geoai
import rasterio

raster_url = "https://data.source.coop/opengeos/geoai/naip-train.tif"
raster_path = geoai.download_file(raster_url)

with rasterio.open(raster_path) as src:
    print(f"Shape: {src.height} x {src.width}")
    print(f"Bands: {src.count}")
    print(f"CRS: {src.crs}")
    print(f"Resolution: {src.res}")
    band1 = src.read(1)  # Read the first band as a NumPy array
    print(f"Band 1 dtype: {band1.dtype}")
# Out:
# Downloading naip-train.tif: 100%|██████████| 12.1M/12.1M [00:00<00:00, 49.5MB/s]
# Shape: 1126 x 2503
# Bands: 4
# CRS: EPSG:26911
# Resolution: (0.5999999999999953, 0.5999999999996691)
# Band 1 dtype: uint8

# %%
geoai.print_raster_info(raster_path, figsize=(18, 10))

# %%
clip_raster_path = "naip_clip.tif"
geoai.clip_raster_by_bbox(
    raster_path,
    clip_raster_path,
    bbox=(0, 0, 500, 500),
    bands=[1, 2, 3],
    bbox_type="pixel",
)
geoai.view_image(clip_raster_path)

# %%
import geopandas as gpd

vector_url = "https://data.source.coop/opengeos/geoai/naip-train-buildings.geojson"
vector_path = geoai.download_file(vector_url)
gdf = gpd.read_file(vector_path)
print(f"Features: {len(gdf)}")
print(f"CRS: {gdf.crs}")
gdf.head()
# Out:
# Downloading naip-train-buildings.geojson: 334kB [00:00, 1.24MB/s]
# Features: 735
# CRS: EPSG:4326
#    id  height     class                                           geometry
# 0   1       0  building  POLYGON ((-117.60111 47.6502, -117.60109 47.65...
# 1   2       0  building  POLYGON ((-117.6008 47.65042, -117.6008 47.650...
# 2   3       0  building  POLYGON ((-117.60049 47.65046, -117.60049 47.6...
# 3   4       0  building  POLYGON ((-117.60048 47.65021, -117.60035 47.6...
# 4   5       0  building  POLYGON ((-117.60012 47.65046, -117.60012 47.6...

# %%
geoai.print_vector_info(vector_path, figsize=(18, 10))

# %%
geoai.view_vector(
    vector_path,
    raster_path=raster_path,
    outline_only=True,
    edge_color="red",
    figsize=(18, 10),
)
# Out:
# <Axes: >

# %%
gdf_utm = gdf.to_crs(crs="EPSG:26911")  # Reproject to UTM Zone 11N
print(f"Original CRS: {gdf.crs}")
print(f"New CRS: {gdf_utm.crs}")
print(f"Sample coordinates before: {gdf.geometry.iloc[0].centroid}")
print(f"Sample coordinates after:  {gdf_utm.geometry.iloc[0].centroid}")
# Out:
# Original CRS: EPSG:4326
# New CRS: EPSG:26911
# Sample coordinates before: POINT (-117.60099192449297 47.65044331966667)
# Sample coordinates after:  POINT (454866.7711971127 5277624.581184586)

# %%
import leafmap

leafmap.reproject(
    image=raster_path,
    output="naip_reprojected.tif",
    dst_crs="EPSG:3857",
    resampling="bilinear",
)
# Out:
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option DRIVER
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option CRS
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option DRIVER
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option CRS
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option DRIVER
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option CRS
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option TRANSFORM
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option DRIVER
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option DTYPE
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option NODATA
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option WIDTH
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option HEIGHT
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option COUNT
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option CRS
# WARNING:rasterio._env:CPLE_NotSupported in warp options does not support option TRANSFORM
# Reading input: /content/naip_reprojected.tif
#
# Adding overviews...
# Updating dataset tags...
# Writing output to: /content/naip_reprojected.tif

# %%
leafmap.split_raster(
    raster_path,
    out_dir="naip_tiles",
    tile_size=512,
    overlap=128,
)

# %% [markdown]
# ## Exercises
#
# ### Exercise 1: Install and Verify Your Environment
#
# ### Exercise 2: Check GPU Availability
#
# ### Exercise 3: Explore Conda Environment Management
#
# ### Exercise 4: Create an Interactive Map
